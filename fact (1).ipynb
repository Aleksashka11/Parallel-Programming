# %%
import multiprocessing
import time
import multiprocessing as mp
from multiprocessing import Pool, Process
import os
import math
import fact1

print("Розпаралельована функцiя пiдрахунку факторiалу за допомогою рекурсiї:")
start = time.time()
fact1.parallel_factorial1()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
print("Звичайна функцiя пiдрахунку факторiалу за допомогою рекурсiї:")  
start = time.time()
fact1.ordinary_factorial1()
end = time.time()
result = end - start
print("Час виконання: ", result)

print("Розпаралельована функцiя пiдрахунку факторiалу за допомогою циклу:")
start = time.time()
fact1.parallel_factorial2()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
print("Звичайна функцiя пiдрахунку факторiалу за допомогою циклу:")    
start = time.time()
fact1.ordinary_factorial2()
end = time.time()
result = end - start
print("Час виконання: ", result)

print("Розпаралельована функцiя пiдрахунку факторiалу за алгоритму обчислення деревом:")
start = time.time()
fact1.parallel_factorial3()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
print("Звичайна функцiя пiдрахунку факторiалу за допомогою алгоритму обчислення деревом:")
start = time.time()
fact1.ordinary_factorial3()
end = time.time()
result = end - start
print("Час виконання: ", result)
# Out:
# Розпаралельована функцiя пiдрахунку факторiалу за допомогою рекурсiї:
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# Факторіал числа  25 = 15511210043330985984000000
# Факторіал числа  50 = 30414093201713378043612608166064768844377641568960512000000000000
# Час виконання:  0.31351733207702637
# Звичайна функцiя пiдрахунку факторiалу за допомогою рекурсiї:
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# Факторіал числа  25 = 15511210043330985984000000
# Факторіал числа  50 = 30414093201713378043612608166064768844377641568960512000000000000
# Час виконання:  0.007979869842529297
# Розпаралельована функцiя пiдрахунку факторiалу за допомогою циклу:
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# ...
