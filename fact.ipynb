# %%
import multiprocessing
import time
import multiprocessing as mp
from multiprocessing import Pool, Process
import os
import math
import fact1

start = time.time()
fact1.parallel_factorial1()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
    
start = time.time()
fact1.ordinary_factorial1()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
start = time.time()
fact1.parallel_factorial2()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
    
start = time.time()
fact1.ordinary_factorial2()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
start = time.time()
fact1.parallel_factorial3()
end = time.time()
result = end - start
print("Час виконання: ", result)
    
    
start = time.time()
fact1.ordinary_factorial3()
end = time.time()
result = end - start
print("Час виконання: ", result)
# Out:
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# Факторіал числа  25 = 15511210043330985984000000
# Факторіал числа  50 = 30414093201713378043612608166064768844377641568960512000000000000
# Час виконання:  0.3420860767364502
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# Факторіал числа  25 = 15511210043330985984000000
# Факторіал числа  50 = 30414093201713378043612608166064768844377641568960512000000000000
# Час виконання:  0.007978677749633789
# Факторіал числа  5 = 120
# Факторіал числа  10 = 3628800
# Факторіал числа  15 = 1307674368000
# Факторіал числа  20 = 2432902008176640000
# Факторіал числа  25 = 15511210043330985984000000
# Факторіал числа  50 = 30414093201713378043612608166064768844377641568960512000000000000
# Час виконання:  0.3540520668029785
# Факторіал числа  5 = 120
# ...
